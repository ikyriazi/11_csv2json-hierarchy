# %% [markdown]
# The code was based on the solution found here: https://stackoverflow.com/questions/43757965/convert-csv-to-json-tree-structure

# %%
import csv, json

# %%
from collections import defaultdict

# %%
csvFilePath = 'inputOst3.csv'
jsonFilePath = 'whole-output.json'

# %%
def ctree():
    return defaultdict(ctree)

# %%
tree = ctree()

# %%
# rid = row id
# cid = column id

with open(csvFilePath) as csvfile:
        reader = csv.reader(csvfile)
        for rid, row in enumerate(reader): 

            # skipping first header row
            # remove if your csv is headerless
            if rid == 0:
                continue

            # usage of python magic to construct dynamic tree structure and
            # basically grouping csv values under their parents
            print("row " + str(rid) + ": " + str(row))
            
            leaf = tree[row[0]] 
            # leaf is the complete tree structure starting from row[0]
            # example:
            # defaultdict(<function ctree at 0x10f4bf0d0>, {
            # 'Cartographic collection - selected objects': defaultdict(<function ctree at 0x10f4bf0d0>, {
            # 'BackToTheMap': defaultdict(<function ctree at 0x10f4bf0d0>, {}), 
            # 'Paracosm - mindful maps': defaultdict(<function ctree at 0x10f4bf0d0>, {})
            # })})
            
            for cid in range(1, len(row)):
                # exclude empty values (i.e. no projects) from the tree structure
                if row[cid] == "":
                    continue
                
                leaf = leaf[row[cid]]
                print(str(row[cid]) + " | leaf: ")
                print(leaf)
            
            print("")
# Out:
# row 1: ['National Archives in Krakow', 'Cartographic collection - selected objects', 'BackToTheMap']
# Cartographic collection - selected objects | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# BackToTheMap | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 2: ['National Archives in Krakow', 'Cartographic collection - selected objects', 'Paracosm - mindful maps']
# Cartographic collection - selected objects | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {'BackToTheMap': defaultdict(<function ctree at 0x10ef360d0>, {})})
# Paracosm - mindful maps | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 3: ['Jagiellonian Library', 'Średniowieczna astronomia / Medieval Astronomy', 'Loxper virtual guide']
# Średniowieczna astronomia / Medieval Astronomy | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# Loxper virtual guide | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 4: ['Jagiellonian Library', 'Chopin', '']
# Chopin | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 5: ['bpk-Bildagentur', 'Historische Porträtsammlung - Carte de Visite', 'Radikale Gespräche']
# Historische Porträtsammlung - Carte de Visite | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# Radikale Gespräche | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 6: ['Damast-und Frottiermuseum Großschönau', 'Schatzkammer der Damaste', 'Abstract Visioner']
# Schatzkammer der Damaste | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# Abstract Visioner | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 7: ['Deutsches Stuhlbaumuseum Rabenau', 'Stile, Stühle, Meisterwerke', '']
# Stile, Stühle, Meisterwerke | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 8: ['Digitales Archiv Mathematischer Modelle', 'Digitales Archiv Mathematischer Modelle', 'Klingende Mathemodelle in VR']
# Digitales Archiv Mathematischer Modelle | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# Klingende Mathemodelle in VR | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 9: ['Forschungsbibliothek Gotha der Uni Erfurt', 'Georg Forsters Entdeckung der Südsee', '']
# Georg Forsters Entdeckung der Südsee | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 10: ['Gedenkstätte Bautzner Straße Dresden', 'DORT & HIER - Verschobenes Gedächtnis', '']
# DORT & HIER - Verschobenes Gedächtnis | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 11: ['Herzogin Anna Amalia Bibliothek', 'Stadtplan von Paris aus dem Jahr 1739', 'Liquitecture']
# Stadtplan von Paris aus dem Jahr 1739 | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# Liquitecture | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 12: ['Herzogin Anna Amalia Bibliothek', 'Stadtplan von Paris aus dem Jahr 1739', 'Chronoscope Hamburg / Chronoscope World']
# Stadtplan von Paris aus dem Jahr 1739 | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {'Liquitecture': defaultdict(<function ctree at 0x10ef360d0>, {})})
# Chronoscope Hamburg / Chronoscope World | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 13: ['Historische Schauweberei Braunsdorf', 'Webmuster und Textilmaschinen', 'webweb']
# Webmuster und Textilmaschinen | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# webweb | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 14: ['Leibniz-Institut für Länderkunde Leipzig', 'Messtischblätter des Deutschen Reiches zur Provinz Schlesien', '']
# Messtischblätter des Deutschen Reiches zur Provinz Schlesien | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 15: ['Kadan City Museum', 'Franziskaner Kloster in Kaaden Innenräume der Klosterkirche', '']
# Franziskaner Kloster in Kaaden Innenräume der Klosterkirche | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 16: ['Moravian Library in Brno', 'Maps and pictures of Brno', 'Loxper virtual guide']
# Maps and pictures of Brno | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# Loxper virtual guide | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 17: ['Moravian-Silesian Research Library in Ostrava', 'Wooden churches in Těšín Silesia', '']
# Wooden churches in Těšín Silesia | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 18: ['Museum - Naturalienkabinett Waldenburg', 'Barocke Seesternsammlung', 'Radikale Gespräche']
# Barocke Seesternsammlung | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# Radikale Gespräche | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 19: ['Museum für Naturkunde Berlin', 'Ehrenberg Zeichnungen / Ehrenberg Drawings', '']
# Ehrenberg Zeichnungen / Ehrenberg Drawings | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 20: ['Musikinstrumentenmuseum der Uni Leipzig', 'Vier Musikinstrumente aus vier Jahrhunderten', 'Klingende Mathemodelle in VR']
# Vier Musikinstrumente aus vier Jahrhunderten | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# Klingende Mathemodelle in VR | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 21: ['Musikinstrumentenmuseum der Uni Leipzig', 'Vier Musikinstrumente aus vier Jahrhunderten', 'Silbermann Reloaded']
# Vier Musikinstrumente aus vier Jahrhunderten | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {'Klingende Mathemodelle in VR': defaultdict(<function ctree at 0x10ef360d0>, {})})
# Silbermann Reloaded | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 22: ['Musikinstrumentenmuseum der Uni Leipzig', 'Vier Musikinstrumente aus vier Jahrhunderten', 'Chronoscope Hamburg / Chronoscope World']
# Vier Musikinstrumente aus vier Jahrhunderten | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {'Klingende Mathemodelle in VR': defaultdict(<function ctree at 0x10ef360d0>, {}), 'Silbermann Reloaded': defaultdict(<function ctree at 0x10ef360d0>, {})})
# Chronoscope Hamburg / Chronoscope World | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 23: ['Geological Museum, University of Wroclaw', 'Fossils from Sośnica', '']
# Fossils from Sośnica | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 24: ['National Museum in Wroclaw', 'The National Museum in Wrocław', '']
# The National Museum in Wrocław | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 25: ['University Museum, University of Wroclaw', 'Ceremonial academic dresses and colours', '']
# Ceremonial academic dresses and colours | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 26: ['National Library of the Czech Republic', 'Monuments of the Czech Republic in old pictures', '']
# Monuments of the Czech Republic in old pictures | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 27: ['Naturkundemuseum Leipzig', 'Tagebücher der Museumsdirektoren 1932-1946', '#Tagmotion, Tags im Museum']
# Tagebücher der Museumsdirektoren 1932-1946 | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# #Tagmotion, Tags im Museum | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 28: ['Ossolineum / Ossoliński National Institute', 'Wrocław - Dresden: Heritage and Urban History', '']
# Wrocław - Dresden: Heritage and Urban History | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 29: ['Regional Museum in Teplice', "Josef Váchal's ex libris", '']
# Josef Váchal's ex libris | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 30: ['SLUB Dresden', 'Vermessen - Karten und Ansichten im Dreiländereck', '']
# Vermessen - Karten und Ansichten im Dreiländereck | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 31: ['SAVE (SLUB Dresden)', 'Privatfilme Hirsch', '']
# Privatfilme Hirsch | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 32: ['Granitabbaumuseum Königshainer Berge', 'Harte Arbeit, schwerer Stein', 'Ein Tag im Leben eines Steinarbeiters']
# Harte Arbeit, schwerer Stein | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# Ein Tag im Leben eines Steinarbeiters | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 33: ['Schlesisches Museum zu Görlitz', 'Hinterglasbilder aus Kaiserswalde / Lasówka, 1750 - 1900', '']
# Hinterglasbilder aus Kaiserswalde / Lasówka, 1750 - 1900 | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 34: ['Sorbisches Institut Bautzen', 'Satirische Darstellung einer gescheiterten Stadtflucht', '']
# Satirische Darstellung einer gescheiterten Stadtflucht | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 35: ['Staatliche Schlösser, Burgen und Gärten Sachsen gGmbH', 'Radikale Muster – Spritzdekor-Keramik aus Colditz', 'Dackel in Trouble']
# Radikale Muster – Spritzdekor-Keramik aus Colditz | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# Dackel in Trouble | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 36: ['Staatliche Schlösser, Burgen und Gärten Sachsen gGmbH', 'Radikale Muster – Spritzdekor-Keramik aus Colditz', 'Fine Young Radicals']
# Radikale Muster – Spritzdekor-Keramik aus Colditz | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {'Dackel in Trouble': defaultdict(<function ctree at 0x10ef360d0>, {})})
# Fine Young Radicals | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 37: ['Staatliche Schlösser, Burgen und Gärten Sachsen gGmbH', 'Radikale Muster – Spritzdekor-Keramik aus Colditz', 'Radikale Gespräche']
# Radikale Muster – Spritzdekor-Keramik aus Colditz | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {'Dackel in Trouble': defaultdict(<function ctree at 0x10ef360d0>, {}), 'Fine Young Radicals': defaultdict(<function ctree at 0x10ef360d0>, {})})
# Radikale Gespräche | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 38: ['Stadtgeschichtliches Museum Leipzig', 'Historische Daguerreotypien', '']
# Historische Daguerreotypien | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 39: ['Stiftung Deutsches Technikmuseum Berlin', 'Hammer-Sammlung Ludwig Thome', 'HAMMERLORD']
# Hammer-Sammlung Ludwig Thome | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# HAMMERLORD | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 40: ['Stiftung Deutsches Technikmuseum Berlin', 'Hammer-Sammlung Ludwig Thome', '#hammerpairs']
# Hammer-Sammlung Ludwig Thome | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {'HAMMERLORD': defaultdict(<function ctree at 0x10ef360d0>, {})})
# #hammerpairs | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 41: ['Stiftung Kraftwerk Hirschfelde', 'Pläne und Fotos Kraftwerk Hirschfelde', 'Old photos become influencers']
# Pläne und Fotos Kraftwerk Hirschfelde | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# Old photos become influencers | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 42: ['Stiftung Kraftwerk Hirschfelde', 'Pläne und Fotos Kraftwerk Hirschfelde', 'Chronoscope Hamburg / Chronoscope World']
# Pläne und Fotos Kraftwerk Hirschfelde | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {'Old photos become influencers': defaultdict(<function ctree at 0x10ef360d0>, {})})
# Chronoscope Hamburg / Chronoscope World | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 43: ['Education and Research Library of the Pilsen Region', 'German-language periodicals published in Pilsen', '']
# German-language periodicals published in Pilsen | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 44: ['Education and Research Library of the Pilsen Region', 'Personalities of the Pilsen Region', '']
# Personalities of the Pilsen Region | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 45: ['Universitätsbibliothek Chemnitz', 'Illustrierte Modezeitschriften aus dem 19. Jahrhundert', '']
# Illustrierte Modezeitschriften aus dem 19. Jahrhundert | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 46: ['Universitätsbibliothek Leipzig', 'Münzsammlung der UB Leipzig', 'Wishing Well']
# Münzsammlung der UB Leipzig | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# Wishing Well | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 47: ['Universitätsbibliothek TU Bergakademie Freiberg', 'Uniformen nach dem Freiberger Fuß 1768', '']
# Uniformen nach dem Freiberger Fuß 1768 | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 48: ['University of Wroclaw - Institute of Art History', '19th century churches in Silesia and their furnishings', '']
# 19th century churches in Silesia and their furnishings | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 49: ['Verein für Computergenealogie', 'Casualty lists of the First World War - Saxony, Poland, Czechia', '']
# Casualty lists of the First World War - Saxony, Poland, Czechia | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 50: ['ZCOM Zuse-Computer-Museum', 'Zuse-Rechner', 'UHF-converter']
# Zuse-Rechner | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
# UHF-converter | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})
#
# row 51: ['ZCOM Zuse-Computer-Museum', 'Bauelementesammlung der DDR in Streichholzschachteln', '']
# Bauelementesammlung der DDR in Streichholzschachteln | leaf:
# defaultdict(<function ctree at 0x10ef360d0>, {})

# %%
def build_leaf(name, leaf):
    res = {"name": name}
    
    # add children node if the leaf has any children
    if (len(leaf.keys()) > 0):
        res["children"] = [build_leaf(k, v) for k, v in leaf.items()]
        
    # add value=1 in each last leaf (this value is prerequisite for the sunburst construction in d3.js)
    if (len(leaf.keys()) == 0):
        res["value"] = 1
        
    return res

# %%
res = []

# %%
for name, leaf in tree.items():
    res.append(build_leaf(name, leaf))

# %%
print(res)
# Out:
# [{'name': 'National Archives in Krakow', 'children': [{'name': 'Cartographic collection - selected objects', 'children': [{'name': 'BackToTheMap', 'value': 1}, {'name': 'Paracosm - mindful maps', 'value': 1}]}]}, {'name': 'Jagiellonian Library', 'children': [{'name': 'Średniowieczna astronomia / Medieval Astronomy', 'children': [{'name': 'Loxper virtual guide', 'value': 1}]}, {'name': 'Chopin', 'value': 1}]}, {'name': 'bpk-Bildagentur', 'children': [{'name': 'Historische Porträtsammlung - Carte de Visite', 'children': [{'name': 'Radikale Gespräche', 'value': 1}]}]}, {'name': 'Damast-und Frottiermuseum Großschönau', 'children': [{'name': 'Schatzkammer der Damaste', 'children': [{'name': 'Abstract Visioner', 'value': 1}]}]}, {'name': 'Deutsches Stuhlbaumuseum Rabenau', 'children': [{'name': 'Stile, Stühle, Meisterwerke', 'value': 1}]}, {'name': 'Digitales Archiv Mathematischer Modelle', 'children': [{'name': 'Digitales Archiv Mathematischer Modelle', 'children': [{'name': 'Klingende Mathemodelle in VR', 'value': 1}]}]}, {'name': 'Forschungsbibliothek Gotha der Uni Erfurt', 'children': [{'name': 'Georg Forsters Entdeckung der Südsee', 'value': 1}]}, {'name': 'Gedenkstätte Bautzner Straße Dresden', 'children': [{'name': 'DORT & HIER - Verschobenes Gedächtnis', 'value': 1}]}, {'name': 'Herzogin Anna Amalia Bibliothek', 'children': [{'name': 'Stadtplan von Paris aus dem Jahr 1739', 'children': [{'name': 'Liquitecture', 'value': 1}, {'name': 'Chronoscope Hamburg / Chronoscope World', 'value': 1}]}]}, {'name': 'Historische Schauweberei Braunsdorf', 'children': [{'name': 'Webmuster und Textilmaschinen', 'children': [{'name': 'webweb', 'value': 1}]}]}, {'name': 'Leibniz-Institut für Länderkunde Leipzig', 'children': [{'name': 'Messtischblätter des Deutschen Reiches zur Provinz Schlesien', 'value': 1}]}, {'name': 'Kadan City Museum', 'children': [{'name': 'Franziskaner Kloster in Kaaden Innenräume der Klosterkirche', 'value': 1}]}, {'name': 'Moravian Library in Brno', 'children': [{'name': 'Maps and pictures of Brno', 'children': [{'name': 'Loxper virtual guide', 'value': 1}]}]}, {'name': 'Moravian-Silesian Research Library in Ostrava', 'children': [{'name': 'Wooden churches in Těšín Silesia', 'value': 1}]}, {'name': 'Museum - Naturalienkabinett Waldenburg', 'children': [{'name': 'Barocke Seesternsammlung', 'children': [{'name': 'Radikale Gespräche', 'value': 1}]}]}, {'name': 'Museum für Naturkunde Berlin', 'children': [{'name': 'Ehrenberg Zeichnungen / Ehrenberg Drawings', 'value': 1}]}, {'name': 'Musikinstrumentenmuseum der Uni Leipzig', 'children': [{'name': 'Vier Musikinstrumente aus vier Jahrhunderten', 'children': [{'name': 'Klingende Mathemodelle in VR', 'value': 1}, {'name': 'Silbermann Reloaded', 'value': 1}, {'name': 'Chronoscope Hamburg / Chronoscope World', 'value': 1}]}]}, {'name': 'Geological Museum, University of Wroclaw', 'children': [{'name': 'Fossils from Sośnica', 'value': 1}]}, {'name': 'National Museum in Wroclaw', 'children': [{'name': 'The National Museum in Wrocław', 'value': 1}]}, {'name': 'University Museum, University of Wroclaw', 'children': [{'name': 'Ceremonial academic dresses and colours', 'value': 1}]}, {'name': 'National Library of the Czech Republic', 'children': [{'name': 'Monuments of the Czech Republic in old pictures', 'value': 1}]}, {'name': 'Naturkundemuseum Leipzig', 'children': [{'name': 'Tagebücher der Museumsdirektoren 1932-1946', 'children': [{'name': '#Tagmotion, Tags im Museum', 'value': 1}]}]}, {'name': 'Ossolineum / Ossoliński National Institute', 'children': [{'name': 'Wrocław - Dresden: Heritage and Urban History', 'value': 1}]}, {'name': 'Regional Museum in Teplice', 'children': [{'name': "Josef Váchal's ex libris", 'value': 1}]}, {'name': 'SLUB Dresden', 'children': [{'name': 'Vermessen - Karten und Ansichten im Dreiländereck', 'value': 1}]}, {'name': 'SAVE (SLUB Dresden)', 'children': [{'name': 'Privatfilme Hirsch', 'value': 1}]}, {'name': 'Granitabbaumuseum Königshainer Berge', 'chi ...

# %%
# for the sunburst construction (d3.js) we need a root element that will include all hierarchical data
root = {}
root['name'] = "CdV Ost³ 2022"
root['children'] = res

print(root)
# Out:
# {'name': 'CdV Ost³ 2022', 'children': [{'name': 'National Archives in Krakow', 'children': [{'name': 'Cartographic collection - selected objects', 'children': [{'name': 'BackToTheMap', 'value': 1}, {'name': 'Paracosm - mindful maps', 'value': 1}]}]}, {'name': 'Jagiellonian Library', 'children': [{'name': 'Średniowieczna astronomia / Medieval Astronomy', 'children': [{'name': 'Loxper virtual guide', 'value': 1}]}, {'name': 'Chopin', 'value': 1}]}, {'name': 'bpk-Bildagentur', 'children': [{'name': 'Historische Porträtsammlung - Carte de Visite', 'children': [{'name': 'Radikale Gespräche', 'value': 1}]}]}, {'name': 'Damast-und Frottiermuseum Großschönau', 'children': [{'name': 'Schatzkammer der Damaste', 'children': [{'name': 'Abstract Visioner', 'value': 1}]}]}, {'name': 'Deutsches Stuhlbaumuseum Rabenau', 'children': [{'name': 'Stile, Stühle, Meisterwerke', 'value': 1}]}, {'name': 'Digitales Archiv Mathematischer Modelle', 'children': [{'name': 'Digitales Archiv Mathematischer Modelle', 'children': [{'name': 'Klingende Mathemodelle in VR', 'value': 1}]}]}, {'name': 'Forschungsbibliothek Gotha der Uni Erfurt', 'children': [{'name': 'Georg Forsters Entdeckung der Südsee', 'value': 1}]}, {'name': 'Gedenkstätte Bautzner Straße Dresden', 'children': [{'name': 'DORT & HIER - Verschobenes Gedächtnis', 'value': 1}]}, {'name': 'Herzogin Anna Amalia Bibliothek', 'children': [{'name': 'Stadtplan von Paris aus dem Jahr 1739', 'children': [{'name': 'Liquitecture', 'value': 1}, {'name': 'Chronoscope Hamburg / Chronoscope World', 'value': 1}]}]}, {'name': 'Historische Schauweberei Braunsdorf', 'children': [{'name': 'Webmuster und Textilmaschinen', 'children': [{'name': 'webweb', 'value': 1}]}]}, {'name': 'Leibniz-Institut für Länderkunde Leipzig', 'children': [{'name': 'Messtischblätter des Deutschen Reiches zur Provinz Schlesien', 'value': 1}]}, {'name': 'Kadan City Museum', 'children': [{'name': 'Franziskaner Kloster in Kaaden Innenräume der Klosterkirche', 'value': 1}]}, {'name': 'Moravian Library in Brno', 'children': [{'name': 'Maps and pictures of Brno', 'children': [{'name': 'Loxper virtual guide', 'value': 1}]}]}, {'name': 'Moravian-Silesian Research Library in Ostrava', 'children': [{'name': 'Wooden churches in Těšín Silesia', 'value': 1}]}, {'name': 'Museum - Naturalienkabinett Waldenburg', 'children': [{'name': 'Barocke Seesternsammlung', 'children': [{'name': 'Radikale Gespräche', 'value': 1}]}]}, {'name': 'Museum für Naturkunde Berlin', 'children': [{'name': 'Ehrenberg Zeichnungen / Ehrenberg Drawings', 'value': 1}]}, {'name': 'Musikinstrumentenmuseum der Uni Leipzig', 'children': [{'name': 'Vier Musikinstrumente aus vier Jahrhunderten', 'children': [{'name': 'Klingende Mathemodelle in VR', 'value': 1}, {'name': 'Silbermann Reloaded', 'value': 1}, {'name': 'Chronoscope Hamburg / Chronoscope World', 'value': 1}]}]}, {'name': 'Geological Museum, University of Wroclaw', 'children': [{'name': 'Fossils from Sośnica', 'value': 1}]}, {'name': 'National Museum in Wroclaw', 'children': [{'name': 'The National Museum in Wrocław', 'value': 1}]}, {'name': 'University Museum, University of Wroclaw', 'children': [{'name': 'Ceremonial academic dresses and colours', 'value': 1}]}, {'name': 'National Library of the Czech Republic', 'children': [{'name': 'Monuments of the Czech Republic in old pictures', 'value': 1}]}, {'name': 'Naturkundemuseum Leipzig', 'children': [{'name': 'Tagebücher der Museumsdirektoren 1932-1946', 'children': [{'name': '#Tagmotion, Tags im Museum', 'value': 1}]}]}, {'name': 'Ossolineum / Ossoliński National Institute', 'children': [{'name': 'Wrocław - Dresden: Heritage and Urban History', 'value': 1}]}, {'name': 'Regional Museum in Teplice', 'children': [{'name': "Josef Váchal's ex libris", 'value': 1}]}, {'name': 'SLUB Dresden', 'children': [{'name': 'Vermessen - Karten und Ansichten im Dreiländereck', 'value': 1}]}, {'name': 'SAVE (SLUB Dresden)', 'children': [{'name': 'Privatfilme Hirsch', 'value': 1}]}, {'name': 'Grani ...

# %%
# export as json
with open(jsonFilePath, 'w') as jsonFile:
        jsonFile.write(json.dumps(root, indent=1)) # by adding indent=1 we prettify the json output file
